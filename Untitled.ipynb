# %%
from vecs import Vecs
import codecs
import os
import gensim

# %%
embedding_path = 'embedding'
vectors = os.path.join(embedding_path, 'vecs.bin')
vocab = os.path.join(embedding_path, 'vocab.txt')
vecs = Vecs(vocab, vectors)

# %%
print(vecs.vecs[0].shape[1])
tmp_vocab = vecs.vocab
tmp_vectors = vecs.vecs
# Out:
# 300

# %%
converted = 'swivel_wordvec.txt'
fp = codecs.open(converted, 'w','utf-8')
fp.write(str(len(vecs.vocab)) + " " + str(vecs.vecs[0].shape[1])+'\n')
for idx in range(len(vecs.vocab)):
    tmp=tmp_vectors[idx].tolist()
    fp.write(tmp_vocab[idx] + ' ')
    if len(tmp[0]) != 300:
        print('vec dimension error')
    for item in tmp[0]:
        fp.write(str(item)+ ' ')
    fp.write('\n')

# %%
W2V = gensim.models.KeyedVectors.load_word2vec_format('swivel_wordvec.txt')

# %%
W2V.most_similar('맛집')
# Out:
# [('맛집을', 0.4778877794742584),
#  ('한식', 0.4551964998245239),
#  ('먹거리', 0.45300406217575073),
#  ('쇼핑', 0.41094106435775757),
#  ('먹방', 0.3981948792934418),
#  ('야식', 0.39295637607574463),
#  ('스낵', 0.39147019386291504),
#  ('분식집', 0.38939622044563293),
#  ('백종원의', 0.38847243785858154),
#  ('집밥', 0.3878224492073059)]

# %%
W2V.save('temp_swivel.txt',binary=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-00a5bb0beee0> in <module>()
# ----> 1 W2V.save('temp_swivel.txt',binary=True)
#
# ~/.local/lib/python3.5/site-packages/gensim/models/keyedvectors.py in save(self, *args, **kwargs)
#     248         # don't bother storing the cached normalized vectors
#     249         kwargs['ignore'] = kwargs.get('ignore', ['vectors_norm'])
# --> 250         super(WordEmbeddingsKeyedVectors, self).save(*args, **kwargs)
#     251
#     252     def word_vec(self, word, use_norm=False):
#
# ~/.local/lib/python3.5/site-packages/gensim/models/keyedvectors.py in save(self, fname_or_handle, **kwargs)
#     116
#     117     def save(self, fname_or_handle, **kwargs):
# --> 118         super(BaseKeyedVectors, self).save(fname_or_handle, **kwargs)
#     119
#     120     @classmethod
#
# ...

# %%
gensim.models.Word2Vec.load('temp_swivel.txt')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/gensim/models/word2vec.py in load(cls, *args, **kwargs)
#     974         try:
# --> 975             return super(Word2Vec, cls).load(*args, **kwargs)
#     976         except AttributeError:
#
# ~/.local/lib/python3.5/site-packages/gensim/models/base_any2vec.py in load(cls, *args, **kwargs)
#     629         model = super(BaseWordEmbeddingsModel, cls).load(*args, **kwargs)
# --> 630         if model.negative and hasattr(model.wv, 'index2word'):
#     631             model.vocabulary.make_cum_table(model.wv)  # rebuild cum_table from vocabulary
#
# AttributeError: 'Word2VecKeyedVectors' object has no attribute 'negative'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ...

# %%
W2V.save_word2vec_format('temp_swivel.bin', binary=True)

# %%
# !ls -lha temp_swivel.bin
# Out:
# -rw-rw-r-- 1 sghan sghan 228M  6월  6 18:46 temp_swivel.bin

# %%
temp_W2V = gensim.models.KeyedVectors.load_word2vec_format('temp_swivel.bin',binary=True)

# %%
temp_W2V.vocab
# Out:
# {'전세계에': <gensim.models.keyedvectors.Vocab at 0x7f8dafa5f390>,
#  '되겠다고': <gensim.models.keyedvectors.Vocab at 0x7f8dafad4898>,
#  '슬퍼하는': <gensim.models.keyedvectors.Vocab at 0x7f8dafa076a0>,
#  '중반엔': <gensim.models.keyedvectors.Vocab at 0x7f8da374ac50>,
#  '페어리의': <gensim.models.keyedvectors.Vocab at 0x7f8da34bc278>,
#  '물리면서': <gensim.models.keyedvectors.Vocab at 0x7f8da37a7c88>,
#  '곳이지만': <gensim.models.keyedvectors.Vocab at 0x7f8daf3ebe10>,
#  '500대': <gensim.models.keyedvectors.Vocab at 0x7f8daf65ea58>,
#  '복장으로': <gensim.models.keyedvectors.Vocab at 0x7f8dafbd37f0>,
#  '사제월드': <gensim.models.keyedvectors.Vocab at 0x7f8da5984898>,
#  '쿠키의': <gensim.models.keyedvectors.Vocab at 0x7f8dafa51198>,
#  '준비하기': <gensim.models.keyedvectors.Vocab at 0x7f8daf4caac8>,
#  '주제의': <gensim.models.keyedvectors.Vocab at 0x7f8daf5c25f8>,
#  '제기되자': <gensim.models.keyedvectors.Vocab at 0x7f8da31e68d0>,
#  '후딜레이가': <gensim.models.keyedvectors.Vocab at 0x7f8daf62e048>,
# ...
